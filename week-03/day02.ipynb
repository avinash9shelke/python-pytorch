# %% [markdown]
# ### HuggingFace pipelines
# For this session we head to Google Colab and use this Notebook to explore the HuggingFace High Level API, pipelines.
#
# https://huggingface.co/docs/transformers/en/pipeline_tutorial
#
#
# https://colab.research.google.com/drive/1qKydgkkgQrqCm9FkifWdyEeTFXLbAu-w?authuser=1#scrollTo=xzNd3jvbDgfb
