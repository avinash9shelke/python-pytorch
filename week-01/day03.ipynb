# %% [markdown]
# Tokenizing with code

# %%
import tiktoken

encoding = tiktoken.encoding_for_model("gpt-5-nano")

text = "Hi , I am Avinash Shelke and I am a software engineer"
tokens = encoding.encode(text)
print(tokens)
# Out:
# [12194, 1366, 357, 939, 7541, 258, 1229, 41086, 1272, 326, 357, 939, 261, 4305, 36894]

# %%
for token_id in tokens:
    token_text = encoding.decode([token_id])
    print(f"{token_id} = {token_text}")
# Out:
# 12194 = Hi
# 1366 =  ,
# 357 =  I
# 939 =  am
# 7541 =  Av
# 258 = in
# 1229 = ash
# 41086 =  Shel
# 1272 = ke
# 326 =  and
# 357 =  I
# 939 =  am
# 261 =  a
# 4305 =  software
# 36894 =  engineer

# %%
encoding.decode([1229])
# Out:
# 'ash'

# %%
import os
from dotenv import load_dotenv

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
from openai import OpenAI
openai = OpenAI(api_key=api_key)

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "Hi! I'm Avinash!"}
    ]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=messages)
response.choices[0].message.content
# Out:
# 'Hi Avinash! Nice to meet you. How can I help today?\n\nI can assist with things like:\n- Answering questions and explaining concepts\n- Drafting emails, documents, or code\n- brainstorming ideas or solutions\n- Summarizing articles or papers\n- Planning (events, trips, study schedules)\n- Translating or improving text\n\nTell me what you’re aiming to do, and I’ll tailor it for you.'

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "Hi! I'm Avinash!"},
    {"role": "assistant", "content": "Hi Avinash! How can I assist you today?"},
    {"role": "user", "content": "What's my name?"}
    ]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=messages)
response.choices[0].message.content
# Out:
# 'Your name is Avinash—the name you told me earlier. Is there another name or nickname you’d prefer I use? How can I help you today?'
