# %%
# imports

import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

# If you get an error running this cell, then please head over to the troubleshooting notebook!

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
# To give you a preview -- calling OpenAI with these messages is this easy. Any problems, head over to the Troubleshooting notebook.

message = "Hello, GPT! This is my first ever message to you! Hi!"

messages = [{"role": "user", "content": message}]

messages
# Out:
# [{'role': 'user',
#   'content': 'Hello, GPT! This is my first ever message to you! Hi!'}]

# %%
openai = OpenAI()

response = openai.chat.completions.create(model="gpt-5-nano", messages=messages)
response.choices[0].message.content
# Out:
# 'Hi there! Welcome — nice to meet you. I’m here to help with questions, explanations, writing, planning, coding, brainstorming, and more. What would you like to do today?\n\nIf you’re not sure, here are some quick ideas:\n- Explain a concept in simple terms (e.g., photosynthesis, how blockchain works)\n- Draft or edit a message, email, or post\n- Plan something practical (a weekend trip, a study schedule, a meal plan)\n- Help with a coding task or debugging\n- Generate ideas for a story, project, or presentation\n\nA couple quick questions to tailor things:\n- What should I call you?\n- Do you prefer short and concise answers or a bit more detail?\n\nTell me what you’re interested in, and we’ll take it from there.'

# %%
# Let's try out this utility

deep_learning = fetch_website_contents("https://www.geeksforgeeks.org/deep-learning/introduction-deep-learning/")
print(deep_learning)
# Out:
# Introduction to Deep Learning - GeeksforGeeks
#
# Courses
# Tutorials
# Practice
# Jobs
# DSA
# Practice Problems
# C
# C++
# Java
# Python
# JavaScript
# Data Science
# Machine Learning
# Courses
# Linux
# DevOps
# GfG ExperienceHub 2026
# Deep Learning Basics
# Introduction to Deep Learning
# Artificial intelligence vs Machine Learning vs Deep Learning
# Deep Learning Examples: Practical Applications in Real Life
# Challenges in Deep Learning
# Why Deep Learning is Important
# Neural Networks Basics
# What is a Neural Network?
# Types of Neural Networks
# Layers in Artificial Neural Networks (ANN)
# Activation functions in Neural Networks
# Feedforward Neural Network
# Backpropagation in Neural Network
# Deep Learning Models
# Convolutional Neural Network (CNN) in Deep Learning
# Introduction to Recurrent Neural Networks
# What is LSTM - Long Short Term Memory?
# Gated Recurrent Unit Networks
# Transformers in Machine Learning
# Autoencoders in Machine Learning
# Generative Adversarial Network (GAN)
# Deep Learning Frameworks
# TensorFlow Tutorial
# PyTorch Tutorial
# Caffe : Deep Learning Framework
# Apache MXNet - Deep Learning Framework
# Theano in Python
# Model Evaluation
# Gradient Descent Algorithm in Machine Learning
# Momentum-based Gradient Optimizer - ML
# Adagrad Optimizer in Deep Learning
# RMSProp Optimizer in Deep Learning
# What is Adam Optimizer?
# Deep Learning Projects
# Lung Cancer Detection using Convolutional Neural Network (CNN)
# Cat & Dog Classification using Convolutional Neural Network in Python
# Sentiment Analysis with an Recurrent Neural Networks (RNN)
# Text Generation using Recurrent Long Short Term Memory Network
# Machine Translation with Transformer in Python
# Deep Learning Interview Questions
# Data Science Live
# Explore
# Introduction to Deep Learning
# Last Updated :
# 16 Dec, 2025
# Deep Learning is transforming the way machines understand, learn and interact with complex data. Deep learning mimics neural networks of the human brain, it enables computers to autonomously uncover patterns and make informed decisions from vast amounts of unstructured

# %%
# Define our system prompt - you can experiment with this later, changing the last sentence to 'Respond in markdown in Spanish."

system_prompt = """
You are a snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
# Define our user prompt

user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "What is 2 + 2?"}
]

response = openai.chat.completions.create(model="gpt-4.1-nano", messages=messages)
response.choices[0].message.content
# Out:
# '2 + 2 is 4.'

# %%
# See how this function creates exactly the format above

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

# %%
# Try this out, and then try for a few more websites

messages_for(deep_learning)
# Out:
# [{'role': 'system',
#   'content': '\nYou are a snarky assistant that analyzes the contents of a website,\nand provides a short, snarky, humorous summary, ignoring text that might be navigation related.\nRespond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.\n'},
#  {'role': 'user',
#   'content': '\nHere are the contents of a website.\nProvide a short summary of this website.\nIf it includes news or announcements, then summarize these too.\n\nIntroduction to Deep Learning - GeeksforGeeks\n\nCourses\nTutorials\nPractice\nJobs\nDSA\nPractice Problems\nC\nC++\nJava\nPython\nJavaScript\nData Science\nMachine Learning\nCourses\nLinux\nDevOps\nGfG ExperienceHub 2026\nDeep Learning Basics\nIntroduction to Deep Learning\nArtificial intelligence vs Machine Learning vs Deep Learning\nDeep Learning Examples: Practical Applications in Real Life\nChallenges in Deep Learning\nWhy Deep Learning is Important\nNeural Networks Basics\nWhat is a Neural Network?\nTypes of Neural Networks\nLayers in Artificial Neural Networks (ANN)\nActivation functions in Neural Networks\nFeedforward Neural Network\nBackpropagation in Neural Network\nDeep Learning Models\nConvolutional Neural Network (CNN) in Deep Learning\nIntroduction to Recurrent Neural Networks\nWhat is LSTM - Long Short Term Memory?\nGated Recurrent Unit Networks\nTransformers in Machine Learning\nAutoencoders in Machine Learning\nGenerative Adversarial Network (GAN)\nDeep Learning Frameworks\nTensorFlow Tutorial\nPyTorch Tutorial\nCaffe : Deep Learning Framework\nApache MXNet - Deep Learning Framework\nTheano in Python\nModel Evaluation\nGradient Descent Algorithm in Machine Learning\nMomentum-based Gradient Optimizer - ML\nAdagrad Optimizer in Deep Learning\nRMSProp Optimizer in Deep Learning\nWhat is Adam Optimizer?\nDeep Learning Projects\nLung Cancer Detection using Convolutional Neural Network (CNN)\nCat & Dog Classification using Convolutional Neural Network in Python\nSentiment Analysis with an Recurrent Neural Networks (RNN)\nText Generation using Recurrent Long Short Term Memory Network\nMachine Translation with Transformer in Python\nDeep Learning Interview Questions\nData Science Live\nExplore\nIntroduction to Deep Learning\nLast Updated :\n16 Dec, 2025\nDeep Learning is transforming the way machines understand, learn and interact with complex data. Deep learning mimics neural networks of the human brain, it enables computers to autonomously uncover patterns and make informed decisions from vast amounts of unstructured '}]

# %%
# And now: call the OpenAI API. You will get very familiar with this!

def summarize(url):
    website = fetch_website_contents(url)
    response = openai.chat.completions.create(
        model = "gpt-4.1-mini",
        messages = messages_for(website)
    )
    return response.choices[0].message.content

# %%
summarize("https://www.geeksforgeeks.org/deep-learning/introduction-deep-learning")
# Out:
# '# GeeksforGeeks Deep Learning: The Ultimate Nerd Paradise\n\nWelcome to the deep end of the internet where GeeksforGeeks throws you every deep learning concept you never knew you needed. It\'s like your overachieving friend who knows the neural network basics, convolutional this-and-that, and can explain LSTMs while cooking dinner.\n\nHighlights:  \n- Articles from "What even *is* deep learning?" to "Hey, here’s how to build Cat & Dog Classifiers with CNNs."  \n- Tutorials on TensorFlow, PyTorch, and other frameworks that sound like fancy coffees.  \n- Optimizers explained so well your gradient descent won’t feel so lonely anymore.  \n- Interview questions that could either land you a job or make you reconsider your career choices.  \n- Projects to flex on your friends, like lung cancer detection or sentiment analysis—because why not?  \n\nBonus: The content is fresh as of December 16, 2025, so it’s practically future-proof.\n\nIn short, if you want to dive deep into deep learning without drowning, this is your geeky life raft. No fluff, just neural nets doing their thing.'

# %%
# A function to display this nicely in the output, using markdown

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://www.geeksforgeeks.org/deep-learning/introduction-deep-learning")
# Out:
# # Introduction to Deep Learning on GeeksforGeeks: The Ultimate Nerd Playground
#
# Welcome to the never-ending buffet of deep learning goodness! This site is basically a deep dive into all things neural nets — from the basics (what even *is* a neural network?) to the spicy stuff like GANs, Transformers, and LSTMs that sound like fridge models but are actually cutting-edge tech.
#
# They've got tutorials, hands-on projects (like spotting lung cancer or telling dogs apart from cats—because who isn't curious about that), and even interview prep to make sure you're ready to impress your future robot overlords.
#
# **Latest news?** Oh, just a casual update from December 2025 reminding us that deep learning continues to revolutionize how machines get smart—like humans, but without the coffee addiction.
#
# In short: It’s your one-stop shop to go from zero to deep learning hero, with enough jargon to make your head spin but enough practical advice to keep you hooked. Dive in, or prepare to be out-neural-networked! 🤖✨
