# %%
from evaluation import test

# %%
tests = test.load_tests()

# %%
len(tests)
# Out:
# 150

# %%
example = tests[0]
print(example.question)
print(example.category)
print(example.reference_answer)
print(example.keywords)
# Out:
# Who won the prestigious IIOTY award in 2023?
# direct_fact
# Maxine Thompson won the prestigious Insurellm Innovator of the Year (IIOTY) award in 2023.
# ['Maxine', 'Thompson', 'IIOTY']

# %%
from collections import Counter
count = Counter([t.category for t in tests])
count
# Out:
# Counter({'direct_fact': 70,
#          'temporal': 20,
#          'spanning': 20,
#          'comparative': 10,
#          'numerical': 10,
#          'relationship': 10,
#          'holistic': 10})

# %%
from evaluation.eval import evaluate_retrieval, evaluate_answer

# %%
evaluate_retrieval(example)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 evaluate_retrieval(example)
#
# File ~/Desktop/llm-engineering/week-05/evaluation/eval.py:92, in evaluate_retrieval(test, k)
#      81 """
#      82 Evaluate retrieval performance for a test question.
#      83
#    (...)     89     RetrievalEval object with MRR, nDCG, and keyword coverage metrics
#      90 """
#      91 # Retrieve documents using shared answer module
# ---> 92 retrieved_docs = fetch_context(test.question)
#      94 # Calculate MRR (average across all keywords)
#      95 mrr_scores = [calculate_mrr(keyword, retrieved_docs) for keyword in test.keywords]
#
# File ~/Desktop/llm-engineering/week-05/implementation/answer.py:38, in fetch_context(question)
#      34 def fetch_context(question: str) -> list[Document]:
#      35     """
#      36     Retrieve relevant context documents for a question.
#      37     """
# ---> 38     return retriever.invoke(question, k=RETRIEVAL_K)
#
# File ~/Desktop/llm-engineering/.venv/lib/python3.12/site-packages/langchain_core/retrievers.py:222, in BaseRetriever.invoke(self, input, config, **kwargs)
#     220 kwargs_ = kwargs if self._expects_other_args else {}
#     221 if self._new_arg_supported:
# --> 222     result = self._get_relevant_documents(
#     223         input, run_manager=run_manager, **kwargs_
#     224     )
#     225 else:
#     226     result = self._get_relevant_documents(input, **kwargs_)
#
# File ~/Desktop/llm-engineering/.venv/lib/python3.12/site-packages/langchain_core/vectorstores/base.py:1045, in VectorStoreRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#    1043 kwargs_ = self.search_kwargs | kwargs
#    1044 if self.search_type == "similarity":
# -> 1045     docs = self.vectorstore.similarity_search(query, **kwargs_)
#    1046 elif self.search_type == "similarity_score_threshold":
#    1047     docs_and_similarities = (
#    1048         self.vectorstore.similarity_search_with_relevance_scores(
#    1049             query, **kwargs_
#    1050         )
#    1051     )
#
# File ~/Desktop/llm-engineering/.venv/lib/python3.12/site-packages/langchain_chroma/vectorstores.py:748, in Chroma.similarity_search(self, query, k, filter, **kwargs)
#     730 def similarity_search(
#     731     self,
#     732     query: str,
#    (...)    735     **kwargs: Any,
#     736 ) -> list[Document]:
#     737     """Run similarity search with Chroma.
#     738
#     739     Args:
#    (...)    746         List of documents most similar to the query text.
#     747     """
# --> 748     docs_and_scores = self.similarity_search_with_score(
#     749         query,
#     750         k,
#     751         filter=filter,
#     752         **kwargs,
#     753     )
#     754     return [doc for doc, _ in docs_and_scores]
#
# File ~/Desktop/llm-engineering/.venv/lib/python3.12/site-packages/langchain_chroma/vectorstores.py:849, in Chroma.similarity_search_with_score(self, query, k, filter, where_document, **kwargs)
#     847 else:
#     848     query_embedding = self._embedding_function.embed_query(query)
# --> 849     results = self.__query_collection(
#     850         query_embeddings=[query_embedding],
#     851         n_results=k,
#     852         where=filter,
#     853         where_document=where_document,
#     854         **kwargs,
#     855     )
#     857 return _results_to_docs_and_scores(results)
#
# File ~/Desktop/llm-engineering/.venv/lib/python3.12/site-packages/langchain_core/utils/utils.py:51, in xor_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      45     msg = (
#      46         "Exactly one argument in each of the following"
#      47         " groups must be defined:"
#      48         f" {', '.join(invalid_group_names)}"
#      49     )
#      50     raise ValueError(msg)
# ---> 51 return func(*args, **kwargs)
#
# File ~/Desktop/llm-engineering/.venv/lib/python3.12/site-packages/langchain_chroma/vectorstores.py:477, in Chroma.__query_collection(self, query_texts, query_embeddings, n_results, where, where_document, **kwargs)
#     449 @xor_args(("query_texts", "query_embeddings"))
#     450 def __query_collection(
#     451     self,
#    (...)    457     **kwargs: Any,
#     458 ) -> list[Document] | chromadb.QueryResult:
#     459     """Query the chroma collection.
#     460
#     461     Args:
#    (...)    475     See more: https://docs.trychroma.com/reference/py-collection#query
#     476     """
# --> 477     return self._collection.query(
#     478         query_texts=query_texts,
#     479         query_embeddings=query_embeddings,  # type: ignore[arg-type]
#     480         n_results=n_results,
#     481         where=where,  # type: ignore[arg-type]
#     482         where_document=where_document,  # type: ignore[arg-type]
#     483         **kwargs,
#     484     )
#
# File ~/Desktop/llm-engineering/.venv/lib/python3.12/site-packages/chromadb/api/models/Collection.py:263, in Collection.query(self, query_embeddings, query_texts, query_images, query_uris, ids, n_results, where, where_document, include)
#     213 """Query for the K nearest neighbor records in the collection.
#     214
#     215 This is a batch query API. Multiple queries can be performed at once
#    (...)    248     ValueError: If multiple query input types are provided.
#     249 """
#     251 query_request = self._validate_and_prepare_query_request(
#     252     query_embeddings=query_embeddings,
#     253     query_texts=query_texts,
#    (...)    260     include=include,
#     261 )
# --> 263 query_results = self._client._query(
#     264     collection_id=self.id,
#     265     ids=query_request["ids"],
#     266     query_embeddings=query_request["embeddings"],
#     267     n_results=query_request["n_results"],
#     268     where=query_request["where"],
#     269     where_document=query_request["where_document"],
#     270     include=query_request["include"],
#     271     tenant=self.tenant,
#     272     database=self.database,
#     273 )
#     275 return self._transform_query_response(
#     276     response=query_results, include=query_request["include"]
#     277 )
#
# File ~/Desktop/llm-engineering/.venv/lib/python3.12/site-packages/chromadb/api/rust.py:552, in RustBindingsAPI._query(self, collection_id, query_embeddings, ids, n_results, where, where_document, include, tenant, database)
#     536 filtered_ids_amount = len(ids) if ids else 0
#     537 self.product_telemetry_client.capture(
#     538     CollectionQueryEvent(
#     539         collection_uuid=str(collection_id),
#    (...)    549     )
#     550 )
# --> 552 rust_response = self.bindings.query(
#     553     str(collection_id),
#     554     ids,
#     555     query_embeddings,
#     556     n_results,
#     557     json.dumps(where) if where else None,
#     558     json.dumps(where_document) if where_document else None,
#     559     include,
#     560     tenant,
#     561     database,
#     562 )
#     564 return QueryResult(
#     565     ids=rust_response.ids,
#     566     embeddings=rust_response.embeddings,
#    (...)    572     distances=rust_response.distances,
#     573 )
#
# NotFoundError: Error getting collection: Collection [1be1482a-880b-41c6-b277-0dbeda122429] does not exist.

# %%
eval, answer, chunks = evaluate_answer(example)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 eval, answer, chunks = evaluate_answer(example)
#
# File ~/Desktop/llm-engineering/week-05/evaluation/eval.py:127, in evaluate_answer(test)
#     117 """
#     118 Evaluate answer quality using LLM-as-a-judge (async).
#     119
#    (...)    124     Tuple of (AnswerEval object, generated_answer string, retrieved_docs list)
#     125 """
#     126 # Get RAG response using shared answer module
# --> 127 generated_answer, retrieved_docs = answer_question(test.question)
#     129 # LLM judge prompt
#     130 judge_messages = [
#     131     {
#     132         "role": "system",
#    (...)    152     },
#     153 ]
#
# File ~/Desktop/llm-engineering/week-05/implementation/answer.py:54, in answer_question(question, history)
#      50 """
#      51 Answer the given question with RAG; return the answer and the context documents.
#      52 """
#      53 combined = combined_question(question, history)
# ---> 54 docs = fetch_context(combined)
#      55 context = "\n\n".join(doc.page_content for doc in docs)
#      56 system_prompt = SYSTEM_PROMPT.format(context=context)
#
# File ~/Desktop/llm-engineering/week-05/implementation/answer.py:38, in fetch_context(question)
#      34 def fetch_context(question: str) -> list[Document]:
#      35     """
#      36     Retrieve relevant context documents for a question.
#      37     """
# ---> 38     return retriever.invoke(question, k=RETRIEVAL_K)
#
# File ~/Desktop/llm-engineering/.venv/lib/python3.12/site-packages/langchain_core/retrievers.py:222, in BaseRetriever.invoke(self, input, config, **kwargs)
#     220 kwargs_ = kwargs if self._expects_other_args else {}
#     221 if self._new_arg_supported:
# --> 222     result = self._get_relevant_documents(
#     223         input, run_manager=run_manager, **kwargs_
#     224     )
#     225 else:
#     226     result = self._get_relevant_documents(input, **kwargs_)
#
# File ~/Desktop/llm-engineering/.venv/lib/python3.12/site-packages/langchain_core/vectorstores/base.py:1045, in VectorStoreRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#    1043 kwargs_ = self.search_kwargs | kwargs
#    1044 if self.search_type == "similarity":
# -> 1045     docs = self.vectorstore.similarity_search(query, **kwargs_)
#    1046 elif self.search_type == "similarity_score_threshold":
#    1047     docs_and_similarities = (
#    1048         self.vectorstore.similarity_search_with_relevance_scores(
#    1049             query, **kwargs_
#    1050         )
#    1051     )
#
# File ~/Desktop/llm-engineering/.venv/lib/python3.12/site-packages/langchain_chroma/vectorstores.py:748, in Chroma.similarity_search(self, query, k, filter, **kwargs)
#     730 def similarity_search(
#     731     self,
#     732     query: str,
#    (...)    735     **kwargs: Any,
#     736 ) -> list[Document]:
#     737     """Run similarity search with Chroma.
#     738
#     739     Args:
#    (...)    746         List of documents most similar to the query text.
#     747     """
# --> 748     docs_and_scores = self.similarity_search_with_score(
#     749         query,
#     750         k,
#     751         filter=filter,
#     752         **kwargs,
#     753     )
#     754     return [doc for doc, _ in docs_and_scores]
#
# File ~/Desktop/llm-engineering/.venv/lib/python3.12/site-packages/langchain_chroma/vectorstores.py:849, in Chroma.similarity_search_with_score(self, query, k, filter, where_document, **kwargs)
#     847 else:
#     848     query_embedding = self._embedding_function.embed_query(query)
# --> 849     results = self.__query_collection(
#     850         query_embeddings=[query_embedding],
#     851         n_results=k,
#     852         where=filter,
#     853         where_document=where_document,
#     854         **kwargs,
#     855     )
#     857 return _results_to_docs_and_scores(results)
#
# File ~/Desktop/llm-engineering/.venv/lib/python3.12/site-packages/langchain_core/utils/utils.py:51, in xor_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      45     msg = (
#      46         "Exactly one argument in each of the following"
#      47         " groups must be defined:"
#      48         f" {', '.join(invalid_group_names)}"
#      49     )
#      50     raise ValueError(msg)
# ---> 51 return func(*args, **kwargs)
#
# File ~/Desktop/llm-engineering/.venv/lib/python3.12/site-packages/langchain_chroma/vectorstores.py:477, in Chroma.__query_collection(self, query_texts, query_embeddings, n_results, where, where_document, **kwargs)
#     449 @xor_args(("query_texts", "query_embeddings"))
#     450 def __query_collection(
#     451     self,
#    (...)    457     **kwargs: Any,
#     458 ) -> list[Document] | chromadb.QueryResult:
#     459     """Query the chroma collection.
#     460
#     461     Args:
#    (...)    475     See more: https://docs.trychroma.com/reference/py-collection#query
#     476     """
# --> 477     return self._collection.query(
#     478         query_texts=query_texts,
#     479         query_embeddings=query_embeddings,  # type: ignore[arg-type]
#     480         n_results=n_results,
#     481         where=where,  # type: ignore[arg-type]
#     482         where_document=where_document,  # type: ignore[arg-type]
#     483         **kwargs,
#     484     )
#
# File ~/Desktop/llm-engineering/.venv/lib/python3.12/site-packages/chromadb/api/models/Collection.py:263, in Collection.query(self, query_embeddings, query_texts, query_images, query_uris, ids, n_results, where, where_document, include)
#     213 """Query for the K nearest neighbor records in the collection.
#     214
#     215 This is a batch query API. Multiple queries can be performed at once
#    (...)    248     ValueError: If multiple query input types are provided.
#     249 """
#     251 query_request = self._validate_and_prepare_query_request(
#     252     query_embeddings=query_embeddings,
#     253     query_texts=query_texts,
#    (...)    260     include=include,
#     261 )
# --> 263 query_results = self._client._query(
#     264     collection_id=self.id,
#     265     ids=query_request["ids"],
#     266     query_embeddings=query_request["embeddings"],
#     267     n_results=query_request["n_results"],
#     268     where=query_request["where"],
#     269     where_document=query_request["where_document"],
#     270     include=query_request["include"],
#     271     tenant=self.tenant,
#     272     database=self.database,
#     273 )
#     275 return self._transform_query_response(
#     276     response=query_results, include=query_request["include"]
#     277 )
#
# File ~/Desktop/llm-engineering/.venv/lib/python3.12/site-packages/chromadb/api/rust.py:552, in RustBindingsAPI._query(self, collection_id, query_embeddings, ids, n_results, where, where_document, include, tenant, database)
#     536 filtered_ids_amount = len(ids) if ids else 0
#     537 self.product_telemetry_client.capture(
#     538     CollectionQueryEvent(
#     539         collection_uuid=str(collection_id),
#    (...)    549     )
#     550 )
# --> 552 rust_response = self.bindings.query(
#     553     str(collection_id),
#     554     ids,
#     555     query_embeddings,
#     556     n_results,
#     557     json.dumps(where) if where else None,
#     558     json.dumps(where_document) if where_document else None,
#     559     include,
#     560     tenant,
#     561     database,
#     562 )
#     564 return QueryResult(
#     565     ids=rust_response.ids,
#     566     embeddings=rust_response.embeddings,
#    (...)    572     distances=rust_response.distances,
#     573 )
#
# InvalidArgumentError: Collection expecting embedding with dimension of 384, got 3072

# %%
print(eval.feedback)
print(eval.accuracy)
print(eval.completeness)
print(eval.relevance)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(eval.feedback)
#       2 print(eval.accuracy)
#       3 print(eval.completeness)
#       4 print(eval.relevance)
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'feedback'
